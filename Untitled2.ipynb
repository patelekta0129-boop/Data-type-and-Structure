# %% [markdown]
# **PW Skills Assignment-Data Types and Structures**
#
# **Name:Ekta Patel**
#
# **Course:Data Science with Generative AI**
#
# **Submitted to:PW Skills**
#
# **Date:16/9/2025**

# %% [markdown]
# **Q1.What are data structures and why are they important?**
#
# **Ans:** Data structures are the way of organizing and storing data in a computer so that it can be accessed and used efficiently.They are important because they improve the speed of data retrieval,memory management,and performance of algorithms.
#
# **Q2.Explain the difference between mutable and immutable data types with examples.**
#
# **Ans:** Mutable data types can be changed after they are created.
#
# Example: List-'my_list=[1,2,3]';'my_list.append(4)'
#
# Immutable data type cannot be changed after creation.
#
# Example: Tuple-'my_tuple=(1,2,3)'
#
# **Q3.Describe how dictionaries store data.**
#
# **Ans:** Dictionries store data as key-value pairs,Each key is unique,and it is used to access its corresponding value quickly.
#
# Example:my_dict={"name":"Ekta Patel","Course":"Data Science"}
#
# **Q4.Why might you use a set instesd of a list in Python?**
#
# **Ans:** A set automatically removes duplicate elements and provides faster look-up times than lists.It is useful when you need unique values.
#
# **Q5.What is a string in Python,and how is it different from a list?**
#
# **Ans:** A string is a sequence of characters enclosed in quotes.It is immutable.
# A list is a collection of itmes,which can be changed, and it can store elements of different types.
#
# **Q6.What is a tuple in Python, and how does it relate to dictionaries in Python?**
#
# **Ans:** A tuple is an immutable sequence of elements.Tuples are often used as key in dictionaries because keys need to be immutable.
#
# **Q7.What is s hash table,and how does it relate to dictionaries in Python?**
#
# **Ans:** A hash table is a data structure that stores key-value pairs using a hash function.Dictionaries in Python use hash tables to quickly access values by keys.
#
# **Q8.Can lists contain different mutable types in Python?**
#
# **Ans:** Yes,lists can store elements of different tyoes,including other lists,dictionaries,or tuple.
#
# Example:my_list=[1,"Hello",[2,3],{"key":"value"}]
#
# **Q9.Explain why strings,dictionaries,or tuples would be preferable over a list for certain tasks.**
#
# **Ans:**
#
# *  Strings are immutable and useful when you need fixed data.
#
# *  Dictionaries provide fast access to element via keys.
#
# *  Tuples are immutable and can be used as dictionary keys or when data should not change.
#
# **Q10.Explain what strings do.**
#
# **Ans:** Strings are used to represent text in Python.They allow storage and manipulation of characters like letters,symbols,or spaces.
#
# **Q11.What advantages do dictionaries offer over lists for certain tasks?**
#
# **Ans:** Dictionaries provide faster data retrieval through keys and can store data in an unordered manner without duplication in keys, unlike lists.
#
# **Q12.Describe a scenario where using a tuple would be preferable over a list.**
#
# **Ans:** A tuple would be preferable when you want to store data that should not change,like coordinates(x,y) or fixed configuration setting.
#
# **Q13.How do sets handle duplicate values?**
#
# **Ans:** Sets automatically remove duplicate values.When you add duplicate elements,only one instance is stored.
#
# Example:my_set={1,2,3}
#         print(my_set)
#
# **Q14.How does the handle duplicate values in Python?**
#
# **Ans:** Mutable structures like lists allow duplictes,while sets remove duplicates automatically.Dictionaries cannot have duplicate keys but can have duplicate values.
#
# **Q15.Can you modify the elements of a tuple?If not,why?**
#
# **Ans:** No,tuples are immutable,meaning their elements cannot be changed after creation.This ensures data integrity when fixed data is required.
#
# **Q16.What is the time complexity of accessing elements in a dictionary?**
#
# **Ans:** Accessing elements in a dictionary is generally O(1), which means it takes constant time,thanks to hashing.
#
# **Q17.Describe the time complexity of a tuple?Explain with examples of its use cases.**
#
# **Ans:** Accessing elements in a tuple is O(1), as it is a fixed sequence.Use cases include storing coordinates,fixed records,or configuration setting.
#
# **Q18.In what situations are lists preferred over dictionaries?**
#
# **Ans:** Lists are preferred when order matters, duplicates are allowed,and you need to store a collection of items that can be accessed by index.
#
# **Q19.Why are dictionries considered unordered,and how does that affect data retrieval?**
#
# **Ans:** Dictionries are unordered because they do not maintain the order of insertain.However,data is accessed by keys,which ensures fast retrieval despite the unordered structure.
#
# **Q20.Explain the difference between a list and a dictionary in terms of data retrieval.**
#
# **Ans:** A list retrieves data by index and can be slower for searching,while a dictionary retrieves data by key providing faster and more efficient access.

# %% [markdown]
# **Practical Questions with Answers:**

# %% [markdown]
# **Q1. Write a code to create a string with your name and print it.**

# %%
name="Ekta Patel"
print(name)
# Out:
# Ekta Patel

# %% [markdown]
# **Q2.Write a code to find the length of teh string 'Hello World'.**

# %%
s="Hello World"
print(len(s))
# Out:
# 11

# %% [markdown]
# **Q3.Write a code to slice the first 3 characters from the string 'Python Progaming'.**

# %%
s2="Python Progaming"
print(s2[:3])
# Out:
# Pyt

# %% [markdown]
# **Q4.Write a code to convert the string 'hello'to uppercase.*8

# %%
s3="hello"
print(s3.upper())
# Out:
# HELLO

# %% [markdown]
# **Q5.Write a code to replace the word 'apple'with'orange' in the string 'I like apple'.**

# %%
s4="I like apple"
print(s4.replace("apple","orange"))
# Out:
# I like orange

# %% [markdown]
# **Q6.Write a code to create a list with numbers 1 to 5 and print it.**

# %%
lst=[1,2,34,5]
print(lst)
# Out:
# [1, 2, 34, 5]

# %% [markdown]
# **Q7.Write a code to append the number 10 to the list[1,2,3,4].**

# %%
lst2=[1,2,3,4]
lst2.append(10)
print(lst2)
# Out:
# [1, 2, 3, 4, 10]

# %% [markdown]
# **Q8.Write a code to remove the number 3 from the list [1,2,3,4,5].**

# %%
lst3=[1,2,3,4,5]
lst3.remove(3)
print(lst3)
# Out:
# [1, 2, 4, 5]

# %% [markdown]
# **Q9.Write a code to access the second element in yhe list ['a','b','c','d'].**

# %%
lst4=['a','b','c','d']
print(lst4[1])
# Out:
# b

# %% [markdown]
# **Q10.Write a code to reverse the list [10,20,30,40,50].**

# %%
lst5=[10,20,30,40,50]
print(lst5[::-1])
# Out:
# [50, 40, 30, 20, 10]

# %% [markdown]
# **Q11.Write a code to create a tuple with thebelements 100,200,300,and print it.**

# %%
tup=(100,200,300)
print(tup)
# Out:
# (100, 200, 300)

# %% [markdown]
# **Q12.Write a code to access the second-to-last element of the tuple('red','green','blue','yellow').**

# %%
tup2=('red','green','blue','yellow')
print(tup2[-2])
# Out:
# blue

# %% [markdown]
# **Q13.Write a code to find the minimum number in the tuple(10,20,5,15).**

# %%
tup3=(10,20,5,15)
print(min(tup3))
# Out:
# 5

# %% [markdown]
# **Q14.Write a code to find the index of the element 'cat'in the tuple ('dog','cat','rabbit').**

# %%
tup4=('dog','cat','rabbit')
print(tup4.index('cat'))
# Out:
# 1

# %% [markdown]
# **Q15.Write a code to create a tuple containing three different fruits and check if'kiwi'is in it.**

# %%
fruits=('apple','banana','kiwi')
print('kiwi'in fruits)
# Out:
# True

# %% [markdown]
# **Q16.Write a code to create a set with the elements 'a','b','c' and print it.**

# %%
sset={'a','b','c'}
print(sset)
# Out:
# {'c', 'a', 'b'}

# %% [markdown]
# **Q17.Write a code to clear all elements from the set {1,2,3,4,5}.**

# %%
sset2={1,2,3,4,5}
sset2.clear()
print(sset2)
# Out:
# set()

# %% [markdown]
# **Q18.Write a code to remove the elements 4 from the set{1,2,3,4}.**

# %%
sset3={1,2,3,4}
sset3.remove(4)
print(sset3)
# Out:
# {1, 2, 3}

# %% [markdown]
# **Q19.Write a code to find the union of two sets {1,2,3}and {3,4,5}.**

# %%
set1={1,2,3}
set2={3,4,5}
print(set1.union(set2))
# Out:
# {1, 2, 3, 4, 5}

# %% [markdown]
# **Q20.Write a code to find the inersection of two sets {1,2,3}and{2,3,4}.**

# %%
print(set1.intersection(set2))
# Out:
# {3}

# %% [markdown]
# **Q21.Write a code to create a dictionary with the keys 'name','age',and'city'and print it.**

# %%
dict1={'name':'Jhon','age':25,'city':'New York'}
print(dict1)
# Out:
# {'name': 'Jhon', 'age': 25, 'city': 'New York'}

# %% [markdown]
# **Q22.Write s code to add a new key-value pair 'country':
# 'USA'to the dictionary and print it.**

# %%
dict1['country']='USA'
print(dict1)

# %% [markdown]
# **Q23.Write a code to access the value associated with the key 'name'in the dictionary{'name':'Alice','age':30}.**

# %%
dict2={'name':'Alice','age':30}
print(dict2['name'])
# Out:
# Alice

# %% [markdown]
# **Q24.Write a code to remove the key 'age' from the dictionary {'name':'Bob','age':22,'city':'New York'}.**

# %%
dict3={'name':'Bob','age':22,'city':'New York'}
del dict3['age']
print(dict3)
# Out:
# {'name': 'Bob', 'city': 'New York'}

# %% [markdown]
# **Q25.Write a code to check if the key 'city'exixts in the dictionary {'name':'Alice','city':'Paris'}.**

# %%
dict4={'name':'Alice','city':'Paris'}
print('city'in dict4)
# Out:
# True

# %% [markdown]
# **Q26.Write a code to create a list,a tuple,and a dictionary and print them all.**

# %%
lst6=[1,2,3]
tup5=(4,5,6)
dict5={'a':7,'b':8}
print(lst6,tup5,dict5)
# Out:
# [1, 2, 3] (4, 5, 6) {'a': 7, 'b': 8}

# %% [markdown]
# **Q27.Write a code to create a list of 5 random numbers between 1 and 100,sort in ascending order,and print the result.**

# %%
import random
lst7=random.sample(range(1,101),5)
lst7.sort()
print(lst7)
# Out:
# [9, 22, 36, 85, 88]

# %% [markdown]
# **Q28.Write a code to create a list with strings and print the element at the third index.**

# %%
lst8=['apple','banana','cherry','date']
print(lst8[3])
# Out:
# date

# %% [markdown]
# **Q29.Write a code to combine two dictionaries into one and print the result.**

# %%
dict6={'x':1,'y':2}
dict7={'y':3,'z':4}
combined={**dict6,**dict7}
print(combined)
# Out:
# {'x': 1, 'y': 3, 'z': 4}

# %% [markdown]
# **Q30.Write a code to convert a list of strings into a set.**

# %%
lst9=['apple','banana','apple','orange']
set4=set(lst9)
print(set4)
# Out:
# {'apple', 'banana', 'orange'}
